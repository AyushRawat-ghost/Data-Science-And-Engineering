# %%
# %sql
# drop table instagram.goldlayer.dim_security;

# %%
# %run "./Gold_Utilities"

# %%
dim_users_df = spark.table("instagram.silverlayer.silver_instagram_users") \
    .select(
        "user_id","uses_premium_features","privacy_setting_level","two_factor_auth_enabled","biometric_login_used","linked_accounts_count","subscription_status","preferred_content_theme",
        "last_login_date"
    ).distinct()

upsert_to_gold(dim_users_df, "instagram.goldlayer", "dim_security", "user_id")
