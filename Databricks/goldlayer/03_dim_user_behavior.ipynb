# %%
# %sql
# drop table instagram.goldlayer.;

# %%
# %run "./Gold_Utilities"

# %%
dim_behavior_df = spark.table("instagram.silverlayer.silver_instagram_users") \
    .select(
        "user_id", 
        "content_type_preference","weekly_work_hours","volunteer_hours_per_month"
    ).distinct()

upsert_to_gold(dim_behavior_df, "instagram.goldlayer", "dim_behavior", "user_id")
