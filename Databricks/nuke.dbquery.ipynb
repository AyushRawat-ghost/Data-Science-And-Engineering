-- %%
DROP TABLE IF EXISTS instagram.bronzelayer.raw_user_data;
DROP TABLE IF EXISTS instagram.silverlayer.silver_instagram_users;
