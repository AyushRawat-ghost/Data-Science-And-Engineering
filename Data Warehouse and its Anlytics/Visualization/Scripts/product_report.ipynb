# %%
############### Product Report
# Importing Necessary libraries
import pyodbc
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib
from sqlalchemy import create_engine

server = 'LAPTOP-LFBT0G3K'
database = 'DataWarehouse'
driver = '{ODBC Driver 18 for SQL Server}'

# %%
try:
    quoted_driver = urllib.parse.quote_plus(driver)
    connection_uri = (
        f'mssql+pyodbc:///?odbc_connect='
        f'DRIVER={quoted_driver};'
        f'SERVER={server};'
        f'DATABASE={database};'
        f'Trusted_Connection=yes;'
        f'Encrypt=yes;'
        f'TrustServerCertificate=yes;'
    )
    sql_analysis_query="""
                        WITH base_query AS (
                        --1) Base Query: Retrieves core columns from fact_sales and dim_products
                            SELECT
                                f.order_number,
                                f.order_date,
                                f.customer_key,
                                f.sales_amount,
                                f.quantity,
                                p.product_key,
                                p.product_name,
                                p.category,
                                p.subcategory,
                                p.cost
                            FROM gold.fact_sales f
                            LEFT JOIN gold.dim_products p
                                ON f.product_key = p.product_key
                            WHERE order_date IS NOT NULL
                        ),

                        product_aggregations AS (
                        --2) Product Aggregations: Summarizes key metrics at the product level
                        SELECT
                            product_key,
                            product_name,
                            category,
                            subcategory,
                            cost,
                            DATEDIFF(MONTH, MIN(order_date), MAX(order_date)) AS lifespan,
                            MAX(order_date) AS last_sale_date,
                            COUNT(DISTINCT order_number) AS total_orders,
                            COUNT(DISTINCT customer_key) AS total_customers,
                            SUM(sales_amount) AS total_sales,
                            SUM(quantity) AS total_quantity,
                            ROUND(AVG(CAST(sales_amount AS FLOAT) / NULLIF(quantity, 0)),1) AS avg_selling_price

                        FROM base_query
                        GROUP BY
                            product_key,
                            product_name,
                            category,
                            subcategory,
                            cost
                        )

                        --3) Final Query: Combines all product results into one output
                        SELECT
                            product_key,
                            product_name,
                            category,
                            subcategory,
                            cost,
                            last_sale_date,
                            DATEDIFF(MONTH, last_sale_date, GETDATE()) AS recency_in_months,
                            
                            CASE
                                WHEN total_sales > 50000 THEN 'High-Performer'
                                WHEN total_sales >= 10000 THEN 'Mid-Range'
                                ELSE 'Low-Performer'
                            END AS product_segment,

                            lifespan,
                            total_orders,
                            total_sales,
                            total_quantity,
                            total_customers,
                            avg_selling_price,
                            
                            -- Average Order Revenue (AOR)
                            CASE
                                WHEN total_orders = 0 THEN 0
                                ELSE total_sales / total_orders
                            END AS avg_order_revenue,

                            -- Average Monthly Revenue
                            CASE
                                WHEN lifespan = 0 THEN total_sales
                                ELSE total_sales / lifespan
                            END AS avg_monthly_revenue
                        FROM product_aggregations;
    """
    print(f"Attempting to connect to {server}/{database} using driver: {driver}")
    engine = create_engine(connection_uri)
    print("Successfully connected to SQL Server!")
    
    df_product_report=pd.read_sql(sql_analysis_query,engine)


except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Attempting to connect to LAPTOP-LFBT0G3K/DataWarehouse using driver: {ODBC Driver 18 for SQL Server}
# Successfully connected to SQL Server!

# %%
# Test for Data
print('first 5 rows fo sales analysis Data : ')
print(df_product_report.head())
print('\nSales Analysis Data info : ')
print(df_product_report.info())
# Out:
# first 5 rows fo sales analysis Data :
#    product_key             product_name category     subcategory  cost  \
# 0            3   Mountain-100 Black- 38    Bikes  Mountain Bikes  1898
# 1            4   Mountain-100 Black- 42    Bikes  Mountain Bikes  1898
# 2            5   Mountain-100 Black- 44    Bikes  Mountain Bikes  1898
# 3            6   Mountain-100 Black- 48    Bikes  Mountain Bikes  1898
# 4            7  Mountain-100 Silver- 38    Bikes  Mountain Bikes  1912
#
#   last_sale_date  recency_in_months product_segment  lifespan  total_orders  \
# 0     2011-12-27                161  High-Performer        11            49
# 1     2011-12-27                161  High-Performer        11            45
# 2     2011-12-21                161  High-Performer        11            60
# 3     2011-12-26                161  High-Performer        12            57
# 4     2011-12-22                161  High-Performer        12            58
#
# ...

# %%
# Scatter Plot cost vs avaerage Selling price
df_product_report['total_cost']=df_product_report['cost']*df_product_report['total_quantity']
df_product_report['profit']=df_product_report['total_sales']-df_product_report['total_cost']

plt.figure(figsize=(8,6))
sns.regplot(x='cost', y='avg_selling_price', data=df_product_report, scatter=False, color='gray', line_kws={'linestyle':'--', 'alpha':0.7})
sns.scatterplot(x='cost',y='avg_selling_price',data=df_product_report)
# for i, row in df_product_report.iterrows():
#     plt.text(row['cost'] + 20, row['avg_selling_price'] + 20, row['product_name'],
#              fontsize=8, ha='left', va='bottom', rotation=15)
plt.title('Cost vs Average Selling Price',fontweight='bold')
plt.xlabel('Cost',fontweight='bold')
plt.ylabel('Average Selling Price',fontweight='bold')
plt.grid(True)
plt.show()

# %%
# Assist in Inventory Management
plt.figure(figsize=(8, 6))
ax=sns.histplot(df_product_report['recency_in_months'], bins=5, kde=True) # bins adjusted for small dataset
plt.title('Distribution of Recency in Months',fontweight='bold')
plt.xlabel('Recency in Months',fontweight='bold')
plt.ylabel('Number of Products',fontweight='bold')
for bar in ax.patches:
    bar_height = bar.get_height()
    bar_x = bar.get_x() + bar.get_width() / 2
    ax.text(bar_x, bar_height, f'{int(bar_height)}',ha='center', va='bottom',fontsize=10, color='black')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
product_counts_by_segment = df_product_report['product_segment'].value_counts().reset_index()
product_counts_by_segment.columns = ['product_segment', 'count_of_products']

# Plotting the bar chart
ax = sns.barplot(x='product_segment', y='count_of_products', data=product_counts_by_segment,order=['High-Performer', 'Mid-Range', 'Low-Performer'],palette='inferno_r')

plt.title('Number of Products by Performance Segment',fontweight='bold')
plt.xlabel('Product Segment',fontweight='bold')
plt.ylabel('Number of Products',fontweight='bold')

for bar in ax.patches:
    ax.text(bar.get_x() + bar.get_width() / 2,bar.get_height(),f'{int(bar.get_height())}',ha='center', va='bottom',fontsize=10, color='black',fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ayush\AppData\Local\Temp\ipykernel_7332\1627368464.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='product_segment', y='count_of_products', data=product_counts_by_segment,order=['High-Performer', 'Mid-Range', 'Low-Performer'],palette='inferno_r')

# %%
plt.figure(figsize=(8, 6))
total_quantity_by_segment = df_product_report.groupby('product_segment')['total_quantity'].sum().reset_index()
total_quantity_by_segment.columns = ['product_segment', 'total_quantity_sold']

segment_order = ['High-Performer', 'Mid-Range', 'Low-Performer']
colors = ['#28a745', '#ffc107', '#dc3545']

ax = sns.barplot(x='product_segment', y='total_quantity_sold', data=total_quantity_by_segment,order=segment_order, palette=colors)

plt.title('Total Quantity Sold/Total Order by Product Segment', fontweight='bold', fontsize=14)
plt.xlabel('Product Segment',fontweight='bold')
plt.ylabel('Total Quantity Sold/Total Order',fontweight='bold')

for bar in ax.patches:
    ax.text(bar.get_x() + bar.get_width() / 2,bar.get_height() + 10,f'{int(bar.get_height())}',ha='center', va='bottom',fontsize=10, color='black')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ayush\AppData\Local\Temp\ipykernel_7332\1561019847.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='product_segment', y='total_quantity_sold', data=total_quantity_by_segment,order=segment_order, palette=colors)

# %%
plt.figure(figsize=(8, 6))
avg_selling_price_by_segment = df_product_report.groupby('product_segment')['avg_selling_price'].mean().reset_index()
avg_selling_price_by_segment.columns = ['product_segment', 'avg_selling_price']

segment_order = ['High-Performer', 'Mid-Range', 'Low-Performer']
colors = ['#28a745', '#ffc107', '#dc3545']

ax = sns.barplot(x='product_segment', y='avg_selling_price', data=avg_selling_price_by_segment,order=segment_order, palette=colors)

plt.title('Average Selling Price/Average Order Revenue by Product Segment', fontweight='bold', fontsize=14)
plt.xlabel('Product Segment',fontweight='bold')
plt.ylabel('Average Selling Price/Average Order Revenue',fontweight='bold')

for bar in ax.patches:
    ax.text(bar.get_x() + bar.get_width() / 2,bar.get_height() + 10,f'{int(bar.get_height())}',ha='center', va='bottom',fontsize=10, color='black')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ayush\AppData\Local\Temp\ipykernel_7332\3897715566.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='product_segment', y='avg_selling_price', data=avg_selling_price_by_segment,order=segment_order, palette=colors)

# %%
plt.figure(figsize=(8, 6))
avg_monthly_revenue_by_segment = df_product_report.groupby('product_segment')['avg_monthly_revenue'].mean().reset_index()
avg_monthly_revenue_by_segment.columns = ['product_segment', 'avg_monthly_revenue']

segment_order = ['High-Performer', 'Mid-Range', 'Low-Performer']
colors = ['#28a745', '#ffc107', '#dc3545']

ax = sns.barplot(x='product_segment', y='avg_monthly_revenue', data=avg_monthly_revenue_by_segment,order=segment_order, palette=colors)

plt.title('Average Monthly Revenue of product by Product Segment', fontweight='bold', fontsize=14)
plt.xlabel('Product Segment',fontweight='bold')
plt.ylabel('Average Monthly Revenue',fontweight='bold')

for bar in ax.patches:
    ax.text(bar.get_x() + bar.get_width() / 2,bar.get_height() + 10,f'{int(bar.get_height())}',ha='center', va='bottom',fontsize=10, color='black')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ayush\AppData\Local\Temp\ipykernel_7332\3154326634.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='product_segment', y='avg_monthly_revenue', data=avg_monthly_revenue_by_segment,order=segment_order, palette=colors)
